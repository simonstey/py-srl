# %% [markdown]
# # SHACL 1.2 Rules — Interactive Playground
#
# A guided tour of the py-srl API: **parse** a rule set, **inspect** its structure, **evaluate** it over a graph, and trace **provenance** and **stratification**.
#
# For focused, runnable feature demos see the numbered scripts in this directory (`01_simple_inference.py` … `12_shape_targeting.py`).

# %% [markdown]
# ## 1. Parse a rule set and inspect its structure
#
# `SRLParser().parse(text)` returns a `RuleSet` AST. Its `prologue`, `rules`, `declarations`, and `data_blocks` are all directly inspectable.

# %%
from srl.parser import SRLParser

EX = "http://example.org/"  # for compacting IRIs to ex:... in printed output

rule_text = """
PREFIX ex: <http://example.org/>

# Base ancestor from parent.
RULE ex:BaseRule {
    # ?x ex:ancestor ?y .
} WHERE {
    # ?x ex:parent ?y .
}

# Transitive ancestor.
RULE ex:RecursiveRule {
    # ?x ex:ancestor ?z .
} WHERE {
    # ?x ex:ancestor ?y .
    # ?y ex:ancestor ?z .
}
"""

rule_set = SRLParser().parse(rule_text)

print(f"prefixes:     {dict(rule_set.prologue.prefixes)}")
print(f"rules:        {len(rule_set.rules)}")
print(f"declarations: {len(rule_set.declarations)}")
print(f"data blocks:  {len(rule_set.data_blocks)}")
for i, rule in enumerate(rule_set.rules):
    name = rule.iri.value.replace(EX, "ex:") if rule.iri else "(anonymous)"
    print(f"  rule {i}: {name}")
# Out:
# prefixes:     {'ex': IRI(value='http://example.org/')}
# rules:        2
# declarations: 0
# data blocks:  0
#   rule 0: ex:BaseRule
#   rule 1: ex:RecursiveRule

# %% [markdown]
# ## 2. Evaluate over a graph
#
# Build an rdflib `Graph`, then `RuleEngine(rule_set).evaluate(graph, inplace=False)`. `inplace=False` leaves the input graph untouched and returns a new result graph (base + inferred).
#
# `evaluate()` returns a fresh graph that does **not** carry the input's custom prefix bindings, so we rebind `ex` for compact `ex:Alice`-style output.

# %%
from rdflib import Graph, Namespace
from srl.engine import RuleEngine

EX = Namespace("http://example.org/")
graph = Graph()
graph.bind("ex", EX)
graph.add((EX.Alice, EX.parent, EX.Bob))
graph.add((EX.Bob, EX.parent, EX.Carol))

engine = RuleEngine(rule_set)
result_graph = engine.evaluate(graph, inplace=False)
result_graph.bind("ex", EX)  # rebind for compact output

print("Inferred triples:")
for s, p, o in sorted(result_graph):
    if (s, p, o) not in graph:
        print(f"  {s.n3(result_graph.namespace_manager)} {p.n3(result_graph.namespace_manager)} {o.n3(result_graph.namespace_manager)}")
print(f"\n{len(graph)} input triples → {len(result_graph)} output triples")
# Out:
# Inferred triples:
#   ex:Alice ex:ancestor ex:Bob
#   ex:Alice ex:ancestor ex:Carol
#   ex:Bob ex:ancestor ex:Carol
#
# 2 input triples → 5 output triples

# %% [markdown]
# ## 3. Provenance: which rule inferred which triple
#
# `evaluate_with_provenance` returns `(graph, [(triple, rule_index, stratum)])`. A `rule_index` of `-1` marks a triple that came from a `DATA` block.

# %%
full_graph, provenance = engine.evaluate_with_provenance(graph, inplace=False)
full_graph.bind("ex", EX)  # rebind for compact output

for triple, rule_idx, stratum in provenance:
    s, p, o = triple
    rule = rule_set.rules[rule_idx] if rule_idx != -1 else None
    source = "DATA" if rule is None else (rule.iri.value.replace(str(EX), "ex:") if rule.iri else f"rule {rule_idx}")
    print(f"[{source}, stratum {stratum}] {s.n3(full_graph.namespace_manager)} {p.n3(full_graph.namespace_manager)} {o.n3(full_graph.namespace_manager)}")
# Out:
# [ex:BaseRule, stratum 0] ex:Bob ex:ancestor ex:Carol
# [ex:BaseRule, stratum 0] ex:Alice ex:ancestor ex:Bob
# [ex:RecursiveRule, stratum 0] ex:Alice ex:ancestor ex:Carol

# %% [markdown]
# ## 4. Stratification layers
#
# `get_stratum_info()` returns the rule indices grouped by evaluation layer. Rules in a later stratum depend (through negation, assignment, or a blank-node head) on rules in earlier strata.

# %%
for layer_num, rule_indices in enumerate(engine.get_stratum_info()):
    names = [
        rule_set.rules[i].iri.value.replace(str(EX), "ex:") if rule_set.rules[i].iri else f"rule{i}"
        for i in rule_indices
    ]
    print(f"stratum {layer_num}: {names}")
# Out:
# stratum 0: ['ex:BaseRule', 'ex:RecursiveRule']

# %%
"""
Example 12: Rule-to-Shape Targeting (opt-in extension)

This is NOT part of the SRL spec -- it is an opt-in extension that scopes a rule
to the focus nodes of a SHACL shape:

    RULE ex:r FOR ?this IN ex:Shape { head } WHERE { body }

Firing a targeted rule is a two-stage filter over the data graph:
  1. the shape's targets (sh:targetClass, sh:targetNode, ...) select candidates;
  2. only candidates that CONFORM to the shape survive.
The wrapped rule then runs once per surviving node, with the focus variable
(?this here) pre-bound to that node.

Enabling it requires the opt-in switches:
  - SRLParser(extensions=True)                     to parse FOR ?v IN <shape>
  - RuleEngine(..., extensions=True, shapes_graph=g)  to evaluate against shapes

On the CLI this is the `srl shacl` subcommand (see README.md).
"""

# Define namespaces
EX = Namespace("http://example.org/")
SH = Namespace("http://www.w3.org/ns/shacl#")

# Data graph: two Persons, only one of whom is an adult.
data_graph = Graph()
data_graph.bind("ex", EX)
data_graph.parse(
    data="""
    @prefix ex: <http://example.org/> .
    ex:Alice a ex:Person ; ex:age 30 .
    ex:Bob   a ex:Person ; ex:age 10 .
    ex:Dave   a ex:Person ; ex:bornYear 2000 .
    """,
    format="turtle",
)

# Shapes graph: AdultShape targets every Person but only conforms at age >= 18.
shapes_graph = Graph()
shapes_graph.parse(
    data="""
    @prefix sh: <http://www.w3.org/ns/shacl#> .
    @prefix ex: <http://example.org/> .
    ex:AdultShape a sh:NodeShape ;
        sh:targetClass ex:Person ;
        sh:property [ sh:path ex:age ; sh:minCount 1 ; sh:minInclusive 18 ] .
    """,
    format="turtle",
)

print("Data:")
for s, p, o in sorted(data_graph):
    print(
        f"  {s.n3(data_graph.namespace_manager)} {p.n3(data_graph.namespace_manager)} {o.n3(data_graph.namespace_manager)}"
    )

# The targeted rule marks conforming focus nodes as adults.
rule_text = """
PREFIX ex: <http://example.org/>

RULE ex:AdultRule FOR ?this IN ex:AdultShape {
    # ?this ex:status ex:adult .
} WHERE {
    # ?this ex:age ?a .
}

RULE {
    # ?person ex:age ?age .
} WHERE {
    # ?person ex:bornYear ?year .
    SET(?age := 2026 - ?year)
}

"""

# extensions=True is required both to PARSE and to EVALUATE the FOR ... IN clause.
parser = SRLParser(extensions=True)
rule_set = parser.parse(rule_text)

# Targeted rules live on a separate list from plain rules.
print(
    f"\nParsed {len(rule_set.rules)} plain rule(s), "
    f"{len(rule_set.targeted_rules)} targeted rule(s):"
)
for tr in rule_set.targeted_rules:
    rule_name = tr.rule.iri.value.replace(str(EX), "ex:")
    shape_name = tr.shape.value.replace(str(EX), "ex:")
    print(f"  {rule_name}: FOR ?{tr.focus_var.name} IN {shape_name}")

engine = RuleEngine(rule_set, extensions=True, shapes_graph=shapes_graph)
result_graph = engine.evaluate(data_graph, inplace=False)
result_graph.bind("ex", EX)  # evaluate() drops custom prefixes; rebind for compact output

# Alice (30) conforms to AdultShape; Bob (10) does not, so only Alice is tagged.
print("\nInferred triples (only shape-conforming focus nodes fire):")
for s, p, o in sorted(result_graph):
    if (s, p, o) not in data_graph:
        print(
            f"  {s.n3(result_graph.namespace_manager)} {p.n3(result_graph.namespace_manager)} {o.n3(result_graph.namespace_manager)}"
        )

print(f"\nTotal: {len(data_graph)} input triples → {len(result_graph)} output triples")
# Out:
# Data:
#   ex:Alice ex:age "30"^^xsd:integer
#   ex:Alice rdf:type ex:Person
#   ex:Bob ex:age "10"^^xsd:integer
#   ex:Bob rdf:type ex:Person
#   ex:Dave ex:bornYear "2000"^^xsd:integer
#   ex:Dave rdf:type ex:Person
#
# Parsed 1 plain rule(s), 1 targeted rule(s):
#   ex:AdultRule: FOR ?this IN ex:AdultShape
#
# Inferred triples (only shape-conforming focus nodes fire):
#   ex:Alice ex:status ex:adult
#   ex:Dave ex:age "26"^^xsd:integer
#   ex:Dave ex:status ex:adult
#
# Total: 6 input triples → 9 output triples

# %%
from rdflib import Graph, Namespace
from rdflib.namespace import RDF

from srl.engine import RuleEngine
from srl.engine.solutions import UnrepresentableTripleTermError
from srl.parser import SRLParser
"""
Example 10: RDF 1.2 Concrete Syntax

SRL accepts RDF 1.2 surface syntax in rule heads/bodies and desugars it to
plain triples during parsing (there are no dedicated RDF 1.2 AST nodes):

    ( a b c )          RDF collection  -> rdf:first / rdf:rest / rdf:nil chain
    [ p1 v1 ; p2 v2 ]  blank-node list -> a fresh blank node with those triples
    << s p o >>        reified triple ) all desugar to an rdf:reifies
    s p o ~r           reifier        ) triple *term* <<( s p o )>>
    s p o {| k v |}    annotation     )

Collections and blank-node property lists desugar to ordinary triples and
evaluate normally. The reification family desugars to RDF 1.2 *triple terms*
(rdf:reifies <<( s p o )>>); those parse, but this rdflib build has no
triple-term type, so evaluating them raises UnrepresentableTripleTermError.
This example demonstrates both outcomes honestly.
"""

# Define namespace
EX = Namespace("http://example.org/")

# --- Part 1: collections + blank-node property lists (evaluate cleanly) ---

graph = Graph()
graph.bind("ex", EX)
graph.bind("rdf", RDF)
graph.add((EX.Cart1, EX.checkout, EX.Now))

print("Input data:")
for s, p, o in sorted(graph):
    print(
        f"  {s.n3(graph.namespace_manager)} {p.n3(graph.namespace_manager)} {o.n3(graph.namespace_manager)}"
    )

# The head builds an ordered list and a nested blank node in one rule.
rule_text = """
PREFIX ex: <http://example.org/>

RULE {
    # ?c ex:items ( "milk" "eggs" "bread" ) .
    # ?c ex:contact [ ex:email "cart@example.org" ; ex:priority 1 ] .
} WHERE {
    # ?c ex:checkout ?when .
}
"""

parser = SRLParser()
rule_set = parser.parse(rule_text)

engine = RuleEngine(rule_set)
result_graph = engine.evaluate(graph, inplace=False)
result_graph.bind("ex", EX)  # evaluate() drops custom prefixes; rebind for compact output
result_graph.bind("rdf", RDF)

# The rdf:first/rdf:rest chain and the blank-node triples are all plain triples.
print("\nResult graph (collection + blank-node list desugared to plain triples):")
for s, p, o in sorted(result_graph, key=str):
    print(
        f"  {s.n3(result_graph.namespace_manager)} {p.n3(result_graph.namespace_manager)} {o.n3(result_graph.namespace_manager)}"
    )

# --- Part 2: reification/annotation (parses, but not evaluable here) ---

reify_text = """
PREFIX ex: <http://example.org/>

RULE {
    # ?s ex:validReading ?r {| ex:derivedBy ex:ValidationRule |} .
} WHERE {
    # ?s ex:rawReading ?r .
}
"""

print("\nReification/annotation rule parses fine:")
reify_rules = parser.parse(reify_text)
print(f"  parsed {len(reify_rules.rules)} rule; head desugared to an rdf:reifies triple term.")

data = Graph()
data.add((EX.Sensor1, EX.rawReading, EX.R1))
try:
    RuleEngine(reify_rules).evaluate(data, inplace=False)
except UnrepresentableTripleTermError as exc:
    print("  ...but evaluating it raises (as documented):")
    print(f"    {type(exc).__name__}: {str(exc).splitlines()[0]}")

print(f"\nTotal: {len(graph)} input triples → {len(result_graph)} output triples")
# Out:
# Input data:
#   ex:Cart1 ex:checkout ex:Now
#
# Result graph (collection + blank-node list desugared to plain triples):
#   _:N16958b2200b84a3492e2aab6479c3f1a rdf:first "eggs"
#   _:N16958b2200b84a3492e2aab6479c3f1a rdf:rest _:Nd59438117b364c248c4cf81a9b5b4eeb
#   _:N5b2d75a85eb94c56828d97fa6e0188c6 rdf:first "milk"
#   _:N5b2d75a85eb94c56828d97fa6e0188c6 rdf:rest _:N16958b2200b84a3492e2aab6479c3f1a
#   _:N7abe2d586dc448cabe500d026ac269d3 ex:email "cart@example.org"
#   _:N7abe2d586dc448cabe500d026ac269d3 ex:priority "1"^^xsd:integer
#   _:Nd59438117b364c248c4cf81a9b5b4eeb rdf:first "bread"
#   _:Nd59438117b364c248c4cf81a9b5b4eeb rdf:rest rdf:nil
#   ex:Cart1 ex:checkout ex:Now
#   ex:Cart1 ex:contact _:N7abe2d586dc448cabe500d026ac269d3
#   ex:Cart1 ex:items _:N5b2d75a85eb94c56828d97fa6e0188c6
#
# Reification/annotation rule parses fine:
#   parsed 1 rule; head desugared to an rdf:reifies triple term.
#   ...but evaluating it raises (as documented):
#     UnrepresentableTripleTermError: This rdflib version has no triple-term type, so the RDF 1.2 triple term <<( http://example.org/Sensor1 http://example.org/validReading http://example.org/R1 )>> cannot be added to the result graph. Triple terms — and the reified-triple / reifier / annotation-block constructs that desugar to rdf:reifies triple terms — parse but are not evaluable here; upgrade to an rdflib with triple-term support to evaluate them.
#
# Total: 1 input triples → 11 output triples

# %% [markdown]
# ## Next steps
#
# The numbered example scripts each isolate one feature:
#
# | Script | Feature |
# | --- | --- |
# | `01_simple_inference.py` | the parse → evaluate → read cycle |
# | `02_rule_forms.py` | `RULE`/`WHERE`, `IF`/`THEN`, named rules |
# | `03_recursion_transitive.py` | recursion + fixpoint |
# | `04_filter_conditions.py` | `FILTER`, `&&`, `IN` |
# | `05_set_and_functions.py` | `SET` + built-in functions |
# | `06_negation.py` | `NOT { … }` |
# | `07_property_paths.py` | sequence `a/b`, inverse `^a` |
# | `08_declarations.py` | `TRANSITIVE`/`SYMMETRIC`/`INVERSE` |
# | `09_data_blocks.py` | `DATA { … }` |
# | `10_rdf12_syntax.py` | collections, blank-node lists, reification |
# | `11_api_provenance.py` | provenance, strata, `results_only` |
# | `12_shape_targeting.py` | rule-to-shape targeting (opt-in extension) |
#
# Run any of them with `uv run python examples/<name>.py`, or use the CLI (`srl parse`/`analyze`/`eval`/`shacl`) as shown in `README.md`.
