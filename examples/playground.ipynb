# %% [markdown]
# ## Example: Transitive Closure
#
# This example shows how to compute transitive closure using
# recursive rules and stratification.

# %%
from rdflib import Graph, Namespace
from srl.engine import RuleEngine
from srl.parser import SRLParser

# Define namespace
EX = Namespace("http://example.org/")

# Create graph with parent relationships
graph = Graph()
graph.bind("ex", EX)

graph.add((EX.Alice, EX.parent, EX.Bob))
graph.add((EX.Bob, EX.parent, EX.Charlie))
graph.add((EX.Charlie, EX.parent, EX.Diana))

print("Input data (parent relationships):")
for s, p, o in graph:
    print(f"  {s.n3(graph.namespace_manager)} {p.n3(graph.namespace_manager)} {o.n3(graph.namespace_manager)}")

# Define recursive rules for transitive closure
rule_text = """
PREFIX ex: <http://example.org/>

# Base case: parent is ancestor
RULE {
    # ?x ex:ancestor ?y .
} WHERE {
    # ?x ex:parent ?y .
}

# Recursive case: ancestor of ancestor
RULE {
    # ?x ex:ancestor ?z .
} WHERE {
    # ?x ex:ancestor ?y .
    # ?y ex:ancestor ?z .
}
"""

# Parse and evaluate
parser = SRLParser()
rule_set = parser.parse(rule_text)

engine = RuleEngine(rule_set)
result_graph = engine.evaluate(graph, inplace=False)

# Show all ancestor relationships
print("\nInferred ancestor relationships:")
for s, p, o in sorted(result_graph):
    if p == EX.ancestor:
        print(f"  {s.n3(result_graph.namespace_manager)} {p.n3(result_graph.namespace_manager)} {o.n3(result_graph.namespace_manager)}")

print(f"\nTotal: {len(graph)} input triples → {len(result_graph)} output triples")
print("Transitive closure computed successfully!")
# Out:
# Input data (parent relationships):
#   ex:Charlie ex:parent ex:Diana
#   ex:Bob ex:parent ex:Charlie
#   ex:Alice ex:parent ex:Bob
#
# Inferred ancestor relationships:
#   <http://example.org/Alice> <http://example.org/ancestor> <http://example.org/Bob>
#   <http://example.org/Alice> <http://example.org/ancestor> <http://example.org/Charlie>
#   <http://example.org/Alice> <http://example.org/ancestor> <http://example.org/Diana>
#   <http://example.org/Bob> <http://example.org/ancestor> <http://example.org/Charlie>
#   <http://example.org/Bob> <http://example.org/ancestor> <http://example.org/Diana>
#   <http://example.org/Charlie> <http://example.org/ancestor> <http://example.org/Diana>
#
# Total: 3 input triples → 9 output triples
# Transitive closure computed successfully!

# %% [markdown]
# ## Example: SET and String Operations
#
# This example shows using SET to assign new variables
# with computed values, including string concatenation.

# %%
from rdflib import Graph, Namespace, Literal
from srl.parser import SRLParser
from srl.engine import RuleEngine

# Define namespace
EX = Namespace("http://example.org/")

# Create graph with name information
graph = Graph()
graph.bind("ex", EX)

graph.add((EX.Person1, EX.firstName, Literal("John")))
graph.add((EX.Person1, EX.lastName, Literal("Doe")))
graph.add((EX.Person2, EX.firstName, Literal("Jane")))
graph.add((EX.Person2, EX.lastName, Literal("Smith")))

print("Input data:")
for s, p, o in sorted(graph):
    print(f"  {s.n3(graph.namespace_manager)} {p.n3(graph.namespace_manager)} {o}")

# Define rule with SET and CONCAT
rule_text = """
PREFIX ex: <http://example.org/>

RULE {
    # ?person ex:fullName ?fullName .
} WHERE {
    # ?person ex:firstName ?first .
    # ?person ex:lastName ?last .
    SET(?fullName := CONCAT(?first, " ", ?last))
}
"""

# Parse and evaluate
parser = SRLParser()
rule_set = parser.parse(rule_text)

engine = RuleEngine(rule_set)
result_graph = engine.evaluate(graph, inplace=False)

# Show generated full names
print("\nGenerated full names:")
for s, p, o in sorted(result_graph):
    if p == EX.fullName:
        print(f"  {s.n3(result_graph.namespace_manager)} -> {o}")

print("SET successfully assigned new variables with CONCAT")

# %%
from rdflib import Graph, Namespace
from srl.parser import SRLParser
from srl.engine import RuleEngine

# Define namespace
EX = Namespace("http://example.org/")

# Create graph with name information
graph = Graph()
graph.bind("ex", EX)

graph.add((EX.Alice, EX.parentOf,EX.Bob))
graph.add((EX.Bob, EX.parentOf,EX.Carol))
graph.add((EX.Carol, EX.parentOf,EX.Dave))

print("Input data:")
for s, p, o in sorted(graph):
    print(f"  {s.n3(graph.namespace_manager)} {p.n3(graph.namespace_manager)} {o.n3(graph.namespace_manager)}")

# Define rule with BIND and CONCAT
rule_text = """
PREFIX ex: <http://example.org/>

# Find grandchildren using path sequence (parent/parent)
RULE { ?grandparent ex:grandchildOf ?grandchild } WHERE {
    # ?grandchild ex:parentOf/ex:parentOf ?grandparent
}

# Find great-grandparents
RULE { ?person ex:greatGrandparent ?ggp } WHERE {
    # ?person ex:parentOf/ex:parentOf/ex:parentOf ?ggp
}
"""

# Parse and evaluate
parser = SRLParser()
rule_set = parser.parse(rule_text)

engine = RuleEngine(rule_set)
result_graph = engine.evaluate(graph)

# Show generated full names
print("\nGenerated full names:")
for s, p, o in sorted(result_graph):
    
     print(f"  {s.n3(graph.namespace_manager)} {p.n3(graph.namespace_manager)} {o.n3(graph.namespace_manager)}")
# Out:
# Input data:
#   ex:Alice ex:parentOf ex:Bob
#   ex:Bob ex:parentOf ex:Carol
#   ex:Carol ex:parentOf ex:Dave
#
# Generated full names:
#   ex:Alice ex:greatGrandparent ex:Bob
#   ex:Alice ex:parentOf ex:Bob
#   ex:Bob ex:grandchildOf ex:Alice
#   ex:Bob ex:greatGrandparent ex:Carol
#   ex:Bob ex:parentOf ex:Carol
#   ex:Carol ex:grandchildOf ex:Bob
#   ex:Carol ex:greatGrandparent ex:Dave
#   ex:Carol ex:parentOf ex:Dave
#   ex:Dave ex:grandchildOf ex:Carol
#
# Generated full names:
#   ex:Alice ex:greatGrandparent ex:Bob
#   ex:Alice ex:parentOf ex:Bob
#   ex:Bob ex:grandchildOf ex:Alice
#   ex:Bob ex:greatGrandparent ex:Carol
#   ex:Bob ex:parentOf ex:Carol
#   ex:Carol ex:grandchildOf ex:Bob
#   ex:Carol ex:greatGrandparent ex:Dave
#   ex:Carol ex:parentOf ex:Dave
#   ex:Dave ex:grandchildOf ex:Carol

# %%
rule_set
# Out:
# RuleSet(prologue=Prologue(base=None, prefixes={Token('PNAME_NS', 'ex:'): IRI(value='http://example.org/')}, version=None, imports=[]), rules=[Rule(head=RuleHead(templates=[TripleTemplate(subject=Variable(name='grandparent'), predicate=IRI(value='http://example.org/grandchildOf'), object=Variable(name='grandchild'))]), body=RuleBody(elements=[TriplePattern(subject=Variable(name='grandchild'), predicate=IRI(value='http://example.org/parentOf'), object=Variable(name='grandparent'))]), layer=None, depends_on=[]), Rule(head=RuleHead(templates=[TripleTemplate(subject=Variable(name='person'), predicate=IRI(value='http://example.org/greatGrandparent'), object=Variable(name='ggp'))]), body=RuleBody(elements=[TriplePattern(subject=Variable(name='person'), predicate=IRI(value='http://example.org/parentOf'), object=Variable(name='ggp'))]), layer=None, depends_on=[])], data_blocks=[], layers=None)

# %%
from rdflib import Graph, Namespace

# Define namespace
EX = Namespace("http://example.org/")

# Create graph with name information
graph = Graph()


print("Input data:")
for s, p, o in sorted(graph):
    print(f"  {s.n3(graph.namespace_manager)} {p.n3(graph.namespace_manager)} {o.n3(graph.namespace_manager)}")

# Define rule with BIND and CONCAT
rule_text = """
PREFIX : <http://example.org/>

# Legal surrogate pair.
:s :p "\uD83C\uDCA1" .

---
# Reversed - illegal surrogate pair.
:s2 :p2 "\uDCA1\uD83C" .

---
# Lone surrogate
:s3 :p3 "\uD83C" .

"""

g = graph.parse(rule_text)

for s, p, o in sorted(g):
     print(f"  {s.n3(graph.namespace_manager)} {p.n3(graph.namespace_manager)} {o.n3(graph.namespace_manager)}")
# Out:
# Exception in callback BaseAsyncIOLoop._handle_events(1372, 1)
# handle: <Handle BaseAsyncIOLoop._handle_events(1372, 1)>
# Traceback (most recent call last):
#   File "f:\Projects\shacl\py-srl\.venv\Lib\site-packages\jupyter_client\session.py", line 103, in json_packer
#     ).encode("utf8", errors="surrogateescape")
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'utf-8' codec can't encode characters in position 121-122: surrogates not allowed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\z00372up\AppData\Roaming\uv\python\cpython-3.12.11-windows-x86_64-none\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "f:\Projects\shacl\py-srl\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
# ...

# %%
from rdflib import Graph, Namespace


# Create graph with name information
graph = Graph()

# Define rule with BIND and CONCAT
rule_text = """
PREFIX : <http://example/>
:s :p "\uD83C\uDCA1" .
"""

g = graph.parse(data=rule_text)

for s, p, o in sorted(g):
    print(f"  {s} {p} {o}")
# Out:
# Exception in callback BaseAsyncIOLoop._handle_events(1372, 1)
# handle: <Handle BaseAsyncIOLoop._handle_events(1372, 1)>
# Traceback (most recent call last):
#   File "f:\Projects\shacl\py-srl\.venv\Lib\site-packages\jupyter_client\session.py", line 103, in json_packer
#     ).encode("utf8", errors="surrogateescape")
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'utf-8' codec can't encode characters in position 64-65: surrogates not allowed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\z00372up\AppData\Roaming\uv\python\cpython-3.12.11-windows-x86_64-none\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "f:\Projects\shacl\py-srl\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
# ...

# %%
from rdflib import Graph, Namespace


# Create graph with name information
graph = Graph()


g = graph.parse(source="1.ttl", format="turtle")



g2 = graph.parse(source="2.ttl", format="turtle")



g3 = graph.parse(source="3.ttl", format="turtle")

g.serialize(destination="1-out.ttl", format="turtle")
g2.serialize(destination="2-out.ttl", format="turtle")  
g3.serialize(destination="3-out.ttl", format="turtle")
# Out:
# <Graph identifier=N0214a7cb590b467aa96c77e16698f6c4 (<class 'rdflib.graph.Graph'>)>

# %%
from rdflib import Graph


files = {
    '../1.ttl': 'Valid surrogate pair   (U+1F0A1 = \U0001F0A1, encoded as \\\\uD83C\\\\uDCA1)',
    '../2.ttl': 'Reversed surrogate pair (\\\\uDCA1\\\\uD83C - illegal)',
    '../3.ttl': 'Lone high surrogate    (\\\\uD83C only - illegal)',
}

for fname, desc in files.items():
    print(f'--- {fname}: {desc} ---')
    raw = open(fname, encoding='utf-8').read()
    print(f'  Raw file content : {repr(raw.strip())}')
    g = Graph()
    try:
        g.parse(source=fname, format='turtle')
        triples = list(g)
        for s, p, o in triples:
            print(f'  Parsed object    : {repr(str(o))}  (codepoints: {[hex(ord(c)) for c in str(o)]})')
        print(f'  Status: OK ({len(triples)} triple(s))')
    except Exception as e:
        print(f'  Status: ERROR - {type(e).__name__}: {e}')
    print()
# Out:
# --- ../1.ttl: Valid surrogate pair   (U+1F0A1 = 🂡, encoded as \\uD83C\\uDCA1) ---
#   Raw file content : '@prefix : <http://example/> .\n:s :p "\\uD83C\\uDCA1" .\n:s :p "\\\\uD83C\\\\uDCA1" .'
#   Parsed object    : '\\uD83C\\uDCA1'  (codepoints: ['0x5c', '0x75', '0x44', '0x38', '0x33', '0x43', '0x5c', '0x75', '0x44', '0x43', '0x41', '0x31'])
#   Parsed object    : '\ud83c\udca1'  (codepoints: ['0xd83c', '0xdca1'])
#   Status: OK (2 triple(s))
#
# --- ../2.ttl: Reversed surrogate pair (\\uDCA1\\uD83C - illegal) ---
#   Raw file content : '@prefix : <http://example/> .\n\n\n# Reversed - illegal surrogate pair.\n:s1 :p1 "\\uDCA1\\uD83C" .\n:s1 :p1 "\\\\uDCA1\\\\uD83C" .'
#   Parsed object    : '\\uDCA1\\uD83C'  (codepoints: ['0x5c', '0x75', '0x44', '0x43', '0x41', '0x31', '0x5c', '0x75', '0x44', '0x38', '0x33', '0x43'])
#   Parsed object    : '\udca1\ud83c'  (codepoints: ['0xdca1', '0xd83c'])
#   Status: OK (2 triple(s))
#
# ...

# %%
from rdflib import Graph

# What *should* 1.ttl be? U+1F0A1 is the PLAYING CARD ACE OF SPADES.
# The pair \uD83C\uDCA1 IS the UTF-16 surrogate encoding of U+1F0A1.
# But rdflib leaves them as raw surrogates instead of recombining them.

g = Graph()
g.parse(source='1.ttl', format='turtle')
for s, p, o in g:
    val = str(o)
    print(f'rdflib stored  : {repr(val)}')
    # Try to decode the surrogate pair manually
    try:
        recombined = val.encode('utf-16', 'surrogatepass').decode('utf-16')
        print(f'Surrogate-pair decoded: {repr(recombined)}  ({recombined})')
        cp = ord(recombined)
        print(f'Code point     : U+{cp:04X}  (expected U+1F0A1 = 🂡, got match: {cp == 0x1F0A1})')
    except Exception as e:
        print(f'Decode failed: {e}')
# Out:
# rdflib stored  : '\\uD83C\\uDCA1'
# Surrogate-pair decoded: '\\uD83C\\uDCA1'  (\uD83C\uDCA1)
# Decode failed: ord() expected a character, but string of length 12 found
# rdflib stored  : '\ud83c\udca1'
# Surrogate-pair decoded: '🂡'  (🂡)
# Code point     : U+1F0A1  (expected U+1F0A1 = 🂡, got match: True)

# %%
from rdflib import Graph

# 2.ttl contains reversed (illegal) surrogate pairs:
#   :s1 :p1 "\uDCA1\uD83C" .   <- low surrogate before high (illegal ordering)
#   :s1 :p1 "\\uDCA1\\uD83C" . <- escaped backslash, stored as literal string

g = Graph()
try:
    g.parse(source='../2.ttl', format='turtle')
    for s, p, o in g:
        val = str(o)
        codepoints = [hex(ord(c)) for c in val]
        print(f'rdflib stored  : {repr(val)}')
        print(f'Code points    : {codepoints}')
        # Attempt surrogate-pair decoding (will fail or produce garbage for illegal order)
        try:
            recombined = val.encode('utf-16', 'surrogatepass').decode('utf-16')
            print(f'Surrogate decode: {repr(recombined)}  (illegal order → garbage or wrong codepoint)')
        except Exception as decode_err:
            print(f'Surrogate decode failed (expected for illegal pair): {decode_err}')
        print()
    print(f'Status: OK — rdflib silently accepted {len(list(g))} triple(s) with illegal surrogate order')
except Exception as e:
    print(f'Status: ERROR — {type(e).__name__}: {e}')
# Out:
# rdflib stored  : '\\uDCA1\\uD83C'
# Code points    : ['0x5c', '0x75', '0x44', '0x43', '0x41', '0x31', '0x5c', '0x75', '0x44', '0x38', '0x33', '0x43']
# Surrogate decode: '\\uDCA1\\uD83C'  (illegal order → garbage or wrong codepoint)
#
# rdflib stored  : '\udca1\ud83c'
# Code points    : ['0xdca1', '0xd83c']
# Surrogate decode failed (expected for illegal pair): 'utf-16-le' codec can't decode bytes in position 2-3: illegal encoding
#
# Status: OK — rdflib silently accepted 2 triple(s) with illegal surrogate order

# %%
from rdflib import Graph

# 3.ttl contains two triples with lone/escaped surrogates:
#   :s2 :p2 "\uD83C"    <- lone high surrogate (no low surrogate follows, illegal)
#   :s2 :p2 "\\uD83C"   <- escaped backslash, stored as the literal string \uD83C

g = Graph()
try:
    g.parse(source='../3.ttl', format='turtle')
    for s, p, o in g:
        val = str(o)
        codepoints = [hex(ord(c)) for c in val]
        print(f'rdflib stored  : {repr(val)}')
        print(f'Code points    : {codepoints}')
        # Attempt surrogate-pair decoding — will fail: lone surrogate has no partner
        try:
            recombined = val.encode('utf-16', 'surrogatepass').decode('utf-16')
            print(f'Surrogate decode: {repr(recombined)}  (unexpected success — lone surrogate decoded)')
        except Exception as decode_err:
            print(f'Surrogate decode failed (expected for lone surrogate): {decode_err}')
        print()
    print(f'Status: OK — rdflib silently accepted {len(list(g))} triple(s) with lone/escaped surrogate(s)')
except Exception as e:
    print(f'Status: ERROR — {type(e).__name__}: {e}')
# Out:
# rdflib stored  : '\\uD83C'
# Code points    : ['0x5c', '0x75', '0x44', '0x38', '0x33', '0x43']
# Surrogate decode: '\\uD83C'  (unexpected success — lone surrogate decoded)
#
# rdflib stored  : '\ud83c'
# Code points    : ['0xd83c']
# Surrogate decode failed (expected for lone surrogate): 'utf-16-le' codec can't decode bytes in position 2-3: unexpected end of data
#
# Status: OK — rdflib silently accepted 2 triple(s) with lone/escaped surrogate(s)

# %%
print()
print('Summary:')
print('  1.ttl \\\\uD83C\\\\uDCA1 -> rdflib silently stores raw surrogates 0xD83C 0xDCA1 (should be U+1F0A1)')
print('  2.ttl \\\\uDCA1\\\\uD83C -> rdflib silently stores raw surrogates 0xDCA1 0xD83C (illegal order, not rejected)')
print('  3.ttl \\\\uD83C         -> rdflib silently stores lone surrogate 0xD83C        (illegal, not rejected)')
